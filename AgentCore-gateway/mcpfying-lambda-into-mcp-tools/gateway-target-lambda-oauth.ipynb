# %% [markdown]
# # AWS Bedrock AgentCore Gateway - Lambda to MCP Tools
#
# This notebook demonstrates how to create an AWS Bedrock AgentCore Gateway that exposes AWS Lambda functions as Model Context Protocol (MCP) tools, enabling seamless integration with AI agents using Strands Agents.
#
# ## Overview
#
# This tutorial covers:
# - Creating an AgentCore Gateway with Cognito-based OAuth authentication (EZAuth flow)
# - Registering Lambda functions as MCP tools
# - Connecting Strands Agents to the gateway
# - Invoking Lambda-backed tools through AI agents
#
# ## Prerequisites
#
# Before running this notebook, ensure you have:
#
# 1. **Python 3.12+** installed
# 2. **AWS CLI** configured with appropriate credentials
# 3. **AWS Account** with permissions for:
#    - Bedrock AgentCore Gateway
#    - AWS Lambda
#    - Amazon Cognito
#    - IAM (for role creation)
# 4. **AWS Profile** configured (or use default credentials)
#
# ---

# %%
# !pip install bedrock_agentcore_starter_toolkit strands-agents strands-agents-tools
# Out:
# Requirement already satisfied: bedrock_agentcore_starter_toolkit in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (0.2.8)
# Requirement already satisfied: strands-agents in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (1.23.0)
# Requirement already satisfied: strands-agents-tools in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (0.2.19)
# Requirement already satisfied: autopep8>=2.3.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (2.3.2)
# Requirement already satisfied: bedrock-agentcore>=1.1.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (1.2.0)
# Requirement already satisfied: boto3>=1.42.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (1.42.34)
# Requirement already satisfied: botocore>=1.42.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (1.42.34)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (0.17.0)
# Requirement already satisfied: httpx>=0.28.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.6 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (3.1.6)
# Requirement already satisfied: openapi-spec-validator>=0.7.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (0.7.2)
# Requirement already satisfied: prance>=25.4.8.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (25.4.8.0)
# Requirement already satisfied: prompt-toolkit>=3.0.51 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (3.0.52)
# Requirement already satisfied: py-openapi-schema-to-json-schema>=0.0.3 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (0.0.3)
# Requirement already satisfied: pydantic<2.41.3,>=2.0.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (2.12.5)
# Requirement already satisfied: pyyaml>=6.0.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (6.0.3)
# Requirement already satisfied: questionary>=2.1.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (2.1.1)
# Requirement already satisfied: requests>=2.25.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (2.32.5)
# Requirement already satisfied: rich>=13.0.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (14.3.1)
# Requirement already satisfied: ruamel-yaml>=0.18.14 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (0.19.1)
# Requirement already satisfied: starlette>=0.46.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (0.46.2)
# Requirement already satisfied: toml>=0.10.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (0.10.2)
# Requirement already satisfied: typer>=0.16.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (0.21.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (2.1.0)
# Requirement already satisfied: uvicorn>=0.34.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock_agentcore_starter_toolkit) (0.35.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents) (4.22.0)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents) (1.25.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents) (1.39.1)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents) (0.60b1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents) (1.39.1)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents) (6.0.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents-tools) (3.9.5)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents-tools) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents-tools) (0.4.1)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents-tools) (1.2.2)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents-tools) (11.3.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents-tools) (2.10.1)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents-tools) (1.27.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents-tools) (1.12)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from strands-agents-tools) (9.1.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.9.4)
# Requirement already satisfied: pycodestyle>=2.12.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from autopep8>=2.3.2->bedrock_agentcore_starter_toolkit) (2.14.0)
# Requirement already satisfied: websockets>=12.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from bedrock-agentcore>=1.1.0->bedrock_agentcore_starter_toolkit) (13.0.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from boto3>=1.42.1->bedrock_agentcore_starter_toolkit) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from boto3>=1.42.1->bedrock_agentcore_starter_toolkit) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from botocore>=1.42.1->bedrock_agentcore_starter_toolkit) (2.9.0.post0)
# Requirement already satisfied: anyio in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from httpx>=0.28.1->bedrock_agentcore_starter_toolkit) (4.12.0)
# Requirement already satisfied: certifi in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from httpx>=0.28.1->bedrock_agentcore_starter_toolkit) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from httpx>=0.28.1->bedrock_agentcore_starter_toolkit) (1.0.5)
# Requirement already satisfied: idna in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from httpx>=0.28.1->bedrock_agentcore_starter_toolkit) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.28.1->bedrock_agentcore_starter_toolkit) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from jinja2>=3.1.6->bedrock_agentcore_starter_toolkit) (2.1.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (0.18.1)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools) (4.12.3)
# Requirement already satisfied: six<2,>=1.15 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools) (1.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (2.12.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (0.0.9)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (3.0.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (0.4.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from openapi-spec-validator>=0.7.2->bedrock_agentcore_starter_toolkit) (0.3.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from openapi-spec-validator>=0.7.2->bedrock_agentcore_starter_toolkit) (1.12.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from openapi-spec-validator>=0.7.2->bedrock_agentcore_starter_toolkit) (0.6.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents) (6.11.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.60b1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (0.60b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (1.17.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.60b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (0.60b1)
# Requirement already satisfied: packaging>=18.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.60b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (26.0)
# Requirement already satisfied: chardet>=5.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from prance>=25.4.8.0->bedrock_agentcore_starter_toolkit) (5.2.0)
# Requirement already satisfied: wcwidth in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from prompt-toolkit>=3.0.51->bedrock_agentcore_starter_toolkit) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from pydantic<2.41.3,>=2.0.0->bedrock_agentcore_starter_toolkit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from pydantic<2.41.3,>=2.0.0->bedrock_agentcore_starter_toolkit) (2.41.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from requests>=2.25.0->bedrock_agentcore_starter_toolkit) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from rich>=13.0.0->bedrock_agentcore_starter_toolkit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from rich>=13.0.0->bedrock_agentcore_starter_toolkit) (2.18.0)
# Requirement already satisfied: slack_sdk<4,>=3.38.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools) (3.39.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from typer>=0.16.0->bedrock_agentcore_starter_toolkit) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from typer>=0.16.0->bedrock_agentcore_starter_toolkit) (1.5.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools) (2.5)
# Requirement already satisfied: zipp>=0.5 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents) (3.20.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-spec-validator>=0.7.2->bedrock_agentcore_starter_toolkit) (0.4.4)
# Requirement already satisfied: mdurl~=0.1 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.0.0->bedrock_agentcore_starter_toolkit) (0.1.2)
# Requirement already satisfied: rfc3339-validator in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-spec-validator>=0.7.2->bedrock_agentcore_starter_toolkit) (0.1.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents) (1.1.1)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents) (42.0.5)
# Requirement already satisfied: cffi>=1.12 in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents) (1.16.0)
# Requirement already satisfied: pycparser in /Users/miladrezaeighale/exit/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents) (2.21)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 2: Import Required Libraries
#
# Import the necessary Python libraries for AWS operations, environment management, and logging.

# %%
import boto3
import os
import logging
import json

# %% [markdown]
# ## Step 3: Configure AWS Environment
#
# Set your AWS region and profile. **Note**: Replace these values with your own AWS configuration.
#
# - `AWS_DEFAULT_REGION`: Your AWS region (e.g., 'us-east-1', 'eu-central-1')
# - `AWS_PROFILE`: Your AWS profile name (optional, uses default if not specified)

# %%
# Configure AWS region and profile
# Replace with your AWS region and profile name
os.environ['AWS_DEFAULT_REGION'] = 'eu-central-1'  # Change to your region
os.environ['AWS_PROFILE'] = 'your-aws-profile'  # Optional: Change to your profile or remove to use default

# %% [markdown]
# ## Step 4: Create AgentCore Gateway with Cognito Authentication
#
# This step creates an AgentCore Gateway using the EZAuth flow, which automatically sets up:
# - Amazon Cognito User Pool
# - Cognito Domain
# - OAuth 2.0 client configuration
# - IAM execution role for the gateway
#
# The gateway will expose Lambda functions as MCP tools that can be discovered and invoked by AI agents.

# %%
from bedrock_agentcore_starter_toolkit.operations.gateway.client import GatewayClient

# Initialize the Gateway client
client = GatewayClient(region_name=os.environ['AWS_DEFAULT_REGION'])
client.logger.setLevel(logging.DEBUG)

# Create Cognito Authorizer using EZAuth flow
# This automatically creates Cognito User Pool, domain, and OAuth client
cognito_authorizer = client.create_oauth_authorizer_with_cognito("agentcore-gateway-test")

# Create the MCP Gateway with Cognito authentication
gateway = client.create_mcp_gateway(authorizer_config=cognito_authorizer["authorizer_config"])

# Extract gateway identifiers
gatewayID = gateway["gatewayId"]
gatewayUrl = gateway["gatewayUrl"]

print(f"✓ Gateway created successfully!")
print(f"Gateway ID: {gatewayID}")
print(f"Gateway URL: {gatewayUrl}")
print(f"\nNote: The gateway URL will be used to connect MCP clients.")
# Out:
# 2026-01-27 16:12:29,394 - bedrock_agentcore.gateway - INFO - Starting EZ Auth setup: Creating Cognito resources...
# 2026-01-27 16:12:31,324 - bedrock_agentcore.gateway - INFO -   ✓ Created User Pool: eu-central-1_M0u24TQ8R
# 2026-01-27 16:12:32,455 - bedrock_agentcore.gateway - INFO -   ✓ Created domain: agentcore-f8b117b8
# 2026-01-27 16:12:32,456 - bedrock_agentcore.gateway - INFO -   ⏳ Waiting for domain to be available...
# 2026-01-27 16:12:32,532 - bedrock_agentcore.gateway - INFO -   ✓ Domain is active
# 2026-01-27 16:12:32,852 - bedrock_agentcore.gateway - INFO -   ✓ Created resource server: agentcore-gateway-test
# 2026-01-27 16:12:33,160 - bedrock_agentcore.gateway - INFO -   ✓ Created client: 2ggnqctruhdplcspij6qohgkrn
# 2026-01-27 16:12:33,160 - bedrock_agentcore.gateway - INFO -   ⏳ Waiting for DNS propagation of domain: agentcore-f8b117b8.auth.eu-central-1.amazoncognito.com
# 2026-01-27 16:13:33,165 - bedrock_agentcore.gateway - INFO - ✓ EZ Auth setup complete!
# 2026-01-27 16:13:33,173 - bedrock_agentcore.gateway - INFO - Role not provided, creating an execution role to use
# 2026-01-27 16:13:33,874 - bedrock_agentcore.gateway - INFO - ✓ Role already exists: arn:aws:iam::911101829662:role/AgentCoreGatewayExecutionRole
# 2026-01-27 16:13:33,875 - bedrock_agentcore.gateway - INFO - ✓ Successfully created execution role for Gateway
# 2026-01-27 16:13:33,876 - bedrock_agentcore.gateway - INFO - Creating Gateway
# 2026-01-27 16:13:33,876 - bedrock_agentcore.gateway - DEBUG - Creating gateway with params: {
#   "name": "TestGateway255362c6",
#   "roleArn": "arn:aws:iam::911101829662:role/AgentCoreGatewayExecutionRole",
#   "protocolType": "MCP",
#   "authorizerType": "CUSTOM_JWT",
#   "authorizerConfiguration": {
#     "customJWTAuthorizer": {
#       "allowedClients": [
#         "2ggnqctruhdplcspij6qohgkrn"
#       ],
#       "discoveryUrl": "https://cognito-idp.eu-central-1.amazonaws.com/eu-central-1_M0u24TQ8R/.well-known/openid-configuration"
#     }
#   },
#   "exceptionLevel": "DEBUG",
#   "protocolConfiguration": {
#     "mcp": {
#       "searchType": "SEMANTIC"
#     }
#   }
# }
# 2026-01-27 16:13:34,109 - bedrock_agentcore.gateway - INFO - ✓ Created Gateway: arn:aws:bedrock-agentcore:eu-central-1:911101829662:gateway/testgateway255362c6-35twl2csmx
# 2026-01-27 16:13:34,110 - bedrock_agentcore.gateway - INFO -   Gateway URL: https://testgateway255362c6-35twl2csmx.gateway.bedrock-agentcore.eu-central-1.amazonaws.com/mcp
# 2026-01-27 16:13:34,110 - bedrock_agentcore.gateway - INFO -   Waiting for Gateway to be ready...
# 2026-01-27 16:13:36,344 - bedrock_agentcore.gateway - INFO -
# ✅Gateway is ready
# ObservabilityDeliveryManager initialized for region: eu-central-1, account: 911101829662
# Created log group: /aws/vendedlogs/bedrock-agentcore/gateway/APPLICATION_LOGS/testgateway255362c6-35twl2csmx
# ✅ Logs delivery enabled for gateway/testgateway255362c6-35twl2csmx
# ✅ Traces delivery enabled for gateway/testgateway255362c6-35twl2csmx
# Observability enabled for gateway/testgateway255362c6-35twl2csmx - logs: True, traces: True
# 2026-01-27 16:13:38,008 - bedrock_agentcore.gateway - INFO - ✅ Observability enabled for gateway testgateway255362c6-35twl2csmx
# 2026-01-27 16:13:38,009 - bedrock_agentcore.gateway - INFO -    Log group: /aws/vendedlogs/bedrock-agentcore/gateway/APPLICATION_LOGS/testgateway255362c6-35twl2csmx
# Gateway ID = testgateway255362c6-35twl2csmx
# Gateway URL = https://testgateway255362c6-35twl2csmx.gateway.bedrock-agentcore.eu-central-1.amazonaws.com/mcp

# %% [markdown]
# ## Create Lambda target

# %%
# This helper will create a lambda by default
lambda_target = client.create_mcp_gateway_target(gateway=gateway, target_type="lambda")
# Out:
# 2026-01-27 16:14:00,328 - bedrock_agentcore.gateway - INFO - ✓ Lambda already exists: arn:aws:lambda:eu-central-1:911101829662:function:AgentCoreLambdaTestFunction
# 2026-01-27 16:14:00,332 - bedrock_agentcore.gateway - INFO - Creating Target
# 2026-01-27 16:14:00,332 - bedrock_agentcore.gateway - INFO - {'gatewayIdentifier': 'testgateway255362c6-35twl2csmx', 'name': 'TestGatewayTarget236f11ee', 'targetConfiguration': {'mcp': {'lambda': {'lambdaArn': 'arn:aws:lambda:eu-central-1:911101829662:function:AgentCoreLambdaTestFunction', 'toolSchema': {'inlinePayload': [{'name': 'get_weather', 'description': 'Get weather for a location', 'inputSchema': {'type': 'object', 'properties': {'location': {'type': 'string'}}, 'required': ['location']}}, {'name': 'get_time', 'description': 'Get time for a timezone', 'inputSchema': {'type': 'object', 'properties': {'timezone': {'type': 'string'}}, 'required': ['timezone']}}]}}}}, 'credentialProviderConfigurations': [{'credentialProviderType': 'GATEWAY_IAM_ROLE'}]}
# 2026-01-27 16:14:00,333 - bedrock_agentcore.gateway - DEBUG - Creating target with params: {
#   "gatewayIdentifier": "testgateway255362c6-35twl2csmx",
#   "name": "TestGatewayTarget236f11ee",
#   "targetConfiguration": {
#     "mcp": {
#       "lambda": {
#         "lambdaArn": "arn:aws:lambda:eu-central-1:911101829662:function:AgentCoreLambdaTestFunction",
#         "toolSchema": {
#           "inlinePayload": [
#             {
#               "name": "get_weather",
#               "description": "Get weather for a location",
#               "inputSchema": {
#                 "type": "object",
#                 "properties": {
#                   "location": {
#                     "type": "string"
#                   }
#                 },
#                 "required": [
#                   "location"
#                 ]
#               }
#             },
#             {
#               "name": "get_time",
#               "description": "Get time for a timezone",
#               "inputSchema": {
#                 "type": "object",
#                 "properties": {
#                   "timezone": {
#                     "type": "string"
#                   }
#                 },
#                 "required": [
#                   "timezone"
#                 ]
#               }
#             }
#           ]
#         }
#       }
#     }
#   },
#   "credentialProviderConfigurations": [
#     {
#       "credentialProviderType": "GATEWAY_IAM_ROLE"
#     }
#   ]
# }
# 2026-01-27 16:14:00,533 - bedrock_agentcore.gateway - INFO - ✓ Added target successfully (ID: BU1XIONEAB)
# 2026-01-27 16:14:00,533 - bedrock_agentcore.gateway - INFO -   Waiting for target to be ready...
# 2026-01-27 16:14:04,934 - bedrock_agentcore.gateway - INFO -
# ✅Target is ready

# %% [markdown]
# ## Adding another Lambda

# %%
lambda_target_configuration = {
    'lambdaArn': 'arn:aws:lambda:eu-central-1:911101829662:function:agentCoreGatewayCustomLambda',
    'toolSchema': {
        # 's3': {
        #     'uri': 'string',
        #     'bucketOwnerAccountId': 'string'
        # },
        'inlinePayload': [
            {
                'name': 'get_random_number',
                'description': 'Returning a random number',
                'inputSchema': {
                    'type': 'object',
                    'properties': {},
                    'required': []
                },
                'outputSchema': {
                    'type': 'integer'
                }
            },
        ]
    }
}

response = client.create_mcp_gateway_target(
    gateway=gateway,
    target_type="lambda",
    target_payload=lambda_target_configuration
)

print("✓ Lambda target added\n")
print(f"Lambda Target = {response}")
# Out:
# 2026-01-27 16:14:27,096 - bedrock_agentcore.gateway - INFO - Creating Target
# 2026-01-27 16:14:27,097 - bedrock_agentcore.gateway - INFO - {'gatewayIdentifier': 'testgateway255362c6-35twl2csmx', 'name': 'TestGatewayTargeta7f3f500', 'targetConfiguration': {'mcp': {'lambda': {'lambdaArn': 'arn:aws:lambda:eu-central-1:911101829662:function:agentCoreGatewayCustomLambda', 'toolSchema': {'inlinePayload': [{'name': 'get_random_number', 'description': 'Returning a random number', 'inputSchema': {'type': 'object', 'properties': {}, 'required': []}, 'outputSchema': {'type': 'integer'}}]}}}}, 'credentialProviderConfigurations': [{'credentialProviderType': 'GATEWAY_IAM_ROLE'}]}
# 2026-01-27 16:14:27,098 - bedrock_agentcore.gateway - DEBUG - Creating target with params: {
#   "gatewayIdentifier": "testgateway255362c6-35twl2csmx",
#   "name": "TestGatewayTargeta7f3f500",
#   "targetConfiguration": {
#     "mcp": {
#       "lambda": {
#         "lambdaArn": "arn:aws:lambda:eu-central-1:911101829662:function:agentCoreGatewayCustomLambda",
#         "toolSchema": {
#           "inlinePayload": [
#             {
#               "name": "get_random_number",
#               "description": "Returning a random number",
#               "inputSchema": {
#                 "type": "object",
#                 "properties": {},
#                 "required": []
#               },
#               "outputSchema": {
#                 "type": "integer"
#               }
#             }
#           ]
#         }
#       }
#     }
#   },
#   "credentialProviderConfigurations": [
#     {
#       "credentialProviderType": "GATEWAY_IAM_ROLE"
#     }
#   ]
# }
# 2026-01-27 16:14:27,360 - bedrock_agentcore.gateway - INFO - ✓ Added target successfully (ID: OEIDUPBOWX)
# 2026-01-27 16:14:27,360 - bedrock_agentcore.gateway - INFO -   Waiting for target to be ready...
# 2026-01-27 16:14:29,654 - bedrock_agentcore.gateway - INFO -
# ✅Target is ready
# ✓ Lambda target added
#
# Lambda Target = {'ResponseMetadata': {'RequestId': '94033087-7331-4a2a-9b3e-d280a12819ac', 'HTTPStatusCode': 202, 'HTTPHeaders': {'date': 'Tue, 27 Jan 2026 15:14:27 GMT', 'content-type': 'application/json', 'content-length': '695', 'connection': 'keep-alive', 'x-amzn-requestid': '94033087-7331-4a2a-9b3e-d280a12819ac', 'x-amzn-remapped-x-amzn-requestid': 'a730ced5-36cc-4f77-bf8c-c81041790635', 'x-amzn-remapped-content-length': '695', 'x-amzn-remapped-connection': 'keep-alive', 'x-amz-apigw-id': 'X2ZtDEhSFiAENjw=', 'x-amzn-trace-id': 'Root=1-6978d653-51631f9549f15a6979931636', 'x-amzn-remapped-date': 'Tue, 27 Jan 2026 15:14:27 GMT'}, 'RetryAttempts': 0}, 'gatewayArn': 'arn:aws:bedrock-agentcore:eu-central-1:911101829662:gateway/testgateway255362c6-35twl2csmx', 'targetId': 'OEIDUPBOWX', 'createdAt': datetime.datetime(2026, 1, 27, 15, 14, 27, 367099, tzinfo=tzutc()), 'updatedAt': datetime.datetime(2026, 1, 27, 15, 14, 27, 367111, tzinfo=tzutc()), 'status': 'CREATING', 'name': 'TestGatewayTargeta7f3f500', 'targetConfiguration': {'mcp': {'lambda': {'lambdaArn': 'arn:aws:lambda:eu-central-1:911101829662:function:agentCoreGatewayCustomLambda', 'toolSchema': {'inlinePayload': [{'name': 'get_random_number', 'description': 'Returning a random number', 'inputSchema': {'type': 'object', 'properties': {}, 'required': []}, 'outputSchema': {'type': 'integer'}}]}}}}, 'credentialProviderConfigurations': [{'credentialProviderType': 'GATEWAY_IAM_ROLE'}]}

# %% [markdown]
# ## Call the MCP tools from Strands Agents

# %%
from strands import Agent
from strands.models import BedrockModel
from strands.tools.mcp.mcp_client import MCPClient
from mcp.client.streamable_http import streamablehttp_client 

# Refresh the access token to ensure it's valid
access_token = client.get_access_token_for_cognito(cognito_authorizer["client_info"])
print(f"✓ Refreshed access token")

# Ensure the gateway URL ends with /mcp
mcp_url = gatewayUrl if gatewayUrl.endswith('/mcp') else f"{gatewayUrl}/mcp"
print(f"✓ Using gateway URL: {mcp_url}")

streamable_http_mcp_client = MCPClient(
    lambda: streamablehttp_client(
        url=mcp_url,
        headers={"Authorization": f"Bearer {access_token}"}
    )    
)

# Start the MCP client and keep it running
streamable_http_mcp_client.start()
print(f"✓ MCP client started")

# Get tools while client is running
tools = streamable_http_mcp_client.list_tools_sync()
print(f"✓ Successfully connected! Found {len(tools)} tools")

# Create agent with the tools
model = BedrockModel(model_id="eu.amazon.nova-pro-v1:0")
agent = Agent(model=model, tools=tools)
print(f"Tools loaded in the agent are {agent.tool_names}")
print(f"\n⚠️  IMPORTANT: Keep the MCP client running while using the agent!")
print(f"   Use streamable_http_mcp_client.stop() when done.")
# Out:
# 2026-01-27 16:27:51,112 - bedrock_agentcore.gateway - INFO - Fetching test token from Cognito...
# 2026-01-27 16:27:51,113 - bedrock_agentcore.gateway - INFO -   Attempting to connect to token endpoint: https://agentcore-f8b117b8.auth.eu-central-1.amazoncognito.com/oauth2/token
# 2026-01-27 16:27:51,801 - bedrock_agentcore.gateway - INFO - ✓ Got test token successfully
# ✓ Refreshed access token
# ✓ Using gateway URL: https://testgateway255362c6-35twl2csmx.gateway.bedrock-agentcore.eu-central-1.amazonaws.com/mcp
# ✓ MCP client started
# ✓ Successfully connected! Found 4 tools
# Tools loaded in the agent are ['x_amz_bedrock_agentcore_search', 'TestGatewayTarget236f11ee___get_time', 'TestGatewayTarget236f11ee___get_weather', 'TestGatewayTargeta7f3f500___get_random_number']
#
# ⚠️  IMPORTANT: Keep the MCP client running while using the agent!
#    Use streamable_http_mcp_client.stop() when done.

# %% [markdown]
# ## Invoking the agent

# %%
# Make sure the MCP client is still running (it should be from Cell 10)
# The agent needs the client session to be active to call tools
response = agent("Get the time for PST")
print("Response: ", response)
# Out:
# <thinking> The user has requested the time for the Pacific Standard Time (PST) timezone. I need to use the `TestGatewayTarget236f11ee___get_time` tool to get the current time for this timezone. </thinking>
#
# Tool #1: TestGatewayTarget236f11ee___get_time
# The current time in the Pacific Standard Time (PST) timezone is 2:30 PM.Response:  The current time in the Pacific Standard Time (PST) timezone is 2:30 PM.

# %% [markdown]
# ## Clean up

# %%
# Stop the MCP client if it's running
try:
    if streamable_http_mcp_client.is_running():
        streamable_http_mcp_client.stop()
        print("✓ MCP client stopped")
except:
    pass

# Clean up gateway resources
client.delete_gateway_target(gatewayID, lambda_target["targetId"])
client.delete_gateway(gatewayID)
print("✓ Gateway resources cleaned up")
# Out:
# 2026-01-27 16:28:16,201 - bedrock_agentcore.gateway - ERROR - target_id or target_name required
# 2026-01-27 16:28:16,420 - bedrock_agentcore.gateway - ERROR - Gateway has 2 target(s). Delete them first.
# ✓ Gateway resources cleaned up

# %% [markdown]
# ## Summary
#
# This notebook demonstrated how to:
#
# 1. ✅ **Create an AgentCore Gateway** with Cognito-based OAuth authentication
# 2. ✅ **Register Lambda functions** as MCP tools with custom schemas
# 3. ✅ **Connect Strands Agents** to discover and use Lambda-backed tools
# 4. ✅ **Invoke tools** through AI agents using natural language
#
# ## Key Takeaways
#
# - **AgentCore Gateway** bridges AWS Lambda functions and AI agents via MCP protocol
# - **EZAuth flow** simplifies Cognito setup for OAuth authentication
# - **Multiple targets** can be registered, each exposing different Lambda functions
# - **Tool schemas** define how Lambda functions are exposed to agents
# - **MCP client** must remain active while agents are using tools
#
# ## Next Steps
#
# - Register your own Lambda functions with custom tool schemas
# - Explore S3-based tool schemas for larger configurations
# - Integrate with other AI agent frameworks that support MCP
# - Set up monitoring and logging for production deployments
#
# ## Additional Resources
#
# - [AWS Bedrock AgentCore Documentation](https://docs.aws.amazon.com/bedrock/)
# - [Model Context Protocol Specification](https://modelcontextprotocol.io/)
# - [Strands Agents Documentation](https://github.com/strands-ai/strands-agents)
# - [Bedrock AgentCore Starter Toolkit](https://github.com/aws-samples/bedrock-agentcore-starter-toolkit)
#
# ---
#
# **Note**: This is a sample implementation. For production use, ensure proper error handling, security best practices, and resource management.
